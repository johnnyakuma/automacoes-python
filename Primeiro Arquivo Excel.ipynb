# %%
import xlsxwriter as opcoesDoXlsxWriter
import os


#selecionando pasta e dando um nome ao arquivo
nomeCaminhoArquivo = 'C:\\Users\\johnn\\Documents\\Curso RPA\\xlsxwriter\\PrimeiroExemplo.xlsx'

workbook = opcoesDoXlsxWriter.Workbook(nomeCaminhoArquivo)

sheetPadrao = workbook.add_worksheet()

#escrevendo no arquivo
sheetPadrao.write("A1","Nome")
sheetPadrao.write("B1","Idade")
sheetPadrao.write("A2","Luffy")
sheetPadrao.write("B2","19")
sheetPadrao.write("A3","Zoro")
sheetPadrao.write("B3","22")

#fechando o arquivo
workbook.close()

#abrindo o arquivo
os.startfile(nomeCaminhoArquivo)

# %%
import xlsxwriter as opcoesDoXlsxWriter
import os


#selecionando pasta e dando um nome ao arquivo
nomeCaminhoArquivo = 'C:\\Users\\johnn\\Documents\\Curso RPA\\xlsxwriter\\PintaFundoEFonte.xlsx'

minhaPlanilha = opcoesDoXlsxWriter.Workbook(nomeCaminhoArquivo)

sheetDados = minhaPlanilha.add_worksheet("Dados")

corFundo = minhaPlanilha.add_format({'fg_color': 'yellow'})
corFonte = minhaPlanilha.add_format({'font_color': 'blue'})
#Outra maneira de dar cor a fonte
#corFonte = minhaPlanilha.add_format()
#corFonte.set.font.format('blue')

#escrevendo no arquivo
sheetDados.write("A1","Nome",corFundo)
sheetDados.write("B1","Idade",corFundo)
sheetDados.write("A2","Luffy",corFonte)
sheetDados.write("B2","19",corFonte)
sheetDados.write("A3","Zoro",corFonte)
sheetDados.write("B3","22",corFonte)

#fechando o arquivo
minhaPlanilha.close()

#abrindo o arquivo
os.startfile(nomeCaminhoArquivo)

# %%
import xlsxwriter as opcoesDoXlsxWriter
import os


#selecionando pasta e dando um nome ao arquivo
nomeCaminhoArquivo = 'C:\\Users\\johnn\\Documents\\Curso RPA\\xlsxwriter\\PintaFundoExemplo.xlsx'

minhaPlanilha = opcoesDoXlsxWriter.Workbook(nomeCaminhoArquivo)

sheetDados = minhaPlanilha.add_worksheet("Dados")

corFundo = minhaPlanilha.add_format({'fg_color': 'yellow'})
corFonte = minhaPlanilha.add_format({'font_color': 'blue'})
#Outra maneira de dar cor a fonte
#corFonte = minhaPlanilha.add_format()
#corFonte.set.font.format('blue')

corFundoFonte = minhaPlanilha.add_format({
    'align':'center',
    'fg_color': 'gray',
    'font_color':'white',
    'bold':'true',
})

#escrevendo no arquivo
sheetDados.write("A1","Nome",corFundoFonte)
sheetDados.write("B1","Idade",corFundoFonte)
sheetDados.write("A2","Luffy",corFonte)
sheetDados.write("B2","19",corFonte)
sheetDados.write("A3","Zoro",corFonte)
sheetDados.write("B3","22",corFonte)

#fechando o arquivo
minhaPlanilha.close()

#abrindo o arquivo
os.startfile(nomeCaminhoArquivo)

# %%
import xlsxwriter as opcoesDoXlsxWriter
import os


#selecionando pasta e dando um nome ao arquivo
nomeCaminhoArquivo = 'C:\\Users\\johnn\\Documents\\Curso RPA\\xlsxwriter\\Formulas.xlsx'

minhaPlanilha = opcoesDoXlsxWriter.Workbook(nomeCaminhoArquivo)

sheetDados = minhaPlanilha.add_worksheet("Dados")

corFundo = minhaPlanilha.add_format({'fg_color': 'yellow'})
corFonte = minhaPlanilha.add_format({'font_color': 'blue'})
#Outra maneira de dar cor a fonte
#corFonte = minhaPlanilha.add_format()
#corFonte.set.font.format('blue')

corFundoFonte = minhaPlanilha.add_format({
    'align':'center',
    'fg_color': 'gray',
    'font_color':'white',
    'bold':'true',
})

#escrevendo no arquivo
sheetDados.write("A1","Numero 1")
sheetDados.write("B1","Numero 2")
sheetDados.write("C1","Resultado")

sheetDados.write("A2",6)
sheetDados.write("A3",7)
sheetDados.write("A4",3)
sheetDados.write("A5",4)

sheetDados.write("B2",4)
sheetDados.write("B3",5)
sheetDados.write("B4",7)
sheetDados.write("B5",8)

sheetDados.write("C2","=Sum(A2+B2)")
sheetDados.write("C3","=Sum(A3+B3)")
sheetDados.write("C4","=Sum(A4+B4)")
sheetDados.write("C5","=Sum(A5+B5)")

#fechando o arquivo
minhaPlanilha.close()

#abrindo o arquivo
os.startfile(nomeCaminhoArquivo)
