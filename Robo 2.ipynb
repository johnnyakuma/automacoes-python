# %%
# !pip install selenium

# %%
from selenium import webdriver

abrir_navegador = webdriver.Chrome()
abrir_navegador.get('https://www.google.com.br/')

# %%
from selenium import webdriver as opcoes_selenium
from selenium.webdriver.common.keys import Keys

#importando a biblioteca do pyautogui para trabalhar com o tempo e teclas do teclado
import pyautogui as tempoPausaComputador

#usando o by para trabalhar com atualizações recentes
from selenium.webdriver.common.by import By

#Passamos autorizaçãso ao acesso as configuracóões do Chrome
meuNavegador = opcoes_selenium.Chrome()
meuNavegador.get('https://www.google.com.br/')

#aguarda o computador processar
tempoPausaComputador.sleep(2)

#procurando pelo elemento NAME e quando encontrador escrever a SEND_KEY
meuNavegador.find_element(By.NAME, 'q').send_keys('Dolar hoje')

#retorna para o campo NAME "Enter"
meuNavegador.find_element(By.NAME, 'q').send_keys(Keys.RETURN)

#No resultado da pesquisa pegamos o XPATH e no meio pegamos o primeiro elemento da lista
valorDolarPeloGoogle = meuNavegador.find_elements(By.XPATH, '//*[@id="knowledge-currency__updatable-data-column"]/div[1]/div[2]/span[1]')[0].text

#aguarda o computador processar
tempoPausaComputador.sleep(2)

print(valorDolarPeloGoogle)
# Out:
# 4,97

# %%
from selenium import webdriver as opcoes_selenium
from selenium.webdriver.common.keys import Keys

#importando a biblioteca do pyautogui para trabalhar com o tempo e teclas do teclado
import pyautogui as tempoPausaComputador
#usando o pyautogui para controlar as teclas do teclado
import pyautogui as teclasAtalhoTeclado
#usando o by para trabalhar com atualizações recentes
from selenium.webdriver.common.by import By

#Passamos autorizaçãso ao acesso as configuracóões do Chrome
meuNavegador = opcoes_selenium.Chrome()
meuNavegador.get('https://www.google.com.br/')

#aguarda o computador processar
tempoPausaComputador.sleep(2)

#procurando pelo elemento NAME e quando encontrador escrever a SEND_KEY
meuNavegador.find_element(By.NAME, 'q').send_keys('Dolar hoje')

#retorna para o campo NAME "Enter"
meuNavegador.find_element(By.NAME, 'q').send_keys(Keys.RETURN)

#No resultado da pesquisa pegamos o XPATH e no meio pegamos o primeiro elemento da lista
valorDolarPeloGoogle = meuNavegador.find_elements(By.XPATH, '//*[@id="knowledge-currency__updatable-data-column"]/div[1]/div[2]/span[1]')[0].text

#aguarda o computador processar
tempoPausaComputador.sleep(2)

print(valorDolarPeloGoogle)


#-----------------------------------------------------------------------------------------
#aguarda o computador processar
tempoPausaComputador.sleep(2)
#seleciona o campo de pesquisa novamente
meuNavegador.find_element(By.NAME, 'q').send_keys("")

#aguarda o computador processar
tempoPausaComputador.sleep(2)
#estamos usando o pyautogui para apertar a tecla TAB
teclasAtalhoTeclado.press('tab')
#aguarda o computador processar
tempoPausaComputador.sleep(2)
#estamos usando o pyautogui para apertar a tecla ENTER para limpar o campo de pesquisa
teclasAtalhoTeclado.press('enter')
#aguarda o computador processar
tempoPausaComputador.sleep(2)
#procurando pelo elemento NAME e quando encontrador escrever a SEND_KEY
meuNavegador.find_element(By.NAME, 'q').send_keys('Euro hoje')
#retorna para o campo NAME "Enter"
meuNavegador.find_element(By.NAME, 'q').send_keys(Keys.RETURN)
#No resultado da pesquisa pegamos o XPATH e no meio pegamos o primeiro elemento da lista
valorEuroPeloGoogle = meuNavegador.find_elements(By.XPATH, '//*[@id="knowledge-currency__updatable-data-column"]/div[1]/div[2]/span[1]')[0].text

#aguarda o computador processar
tempoPausaComputador.sleep(2)

print(valorEuroPeloGoogle)
# Out:
# 4,97
# 5,35

# %%
#ESSE CODIGO FOI APENAS UM TESTE PARA USAR UMA ESTRUTURA BASICA DE IF ELSE

from selenium import webdriver as opcoes_selenium
from selenium.webdriver.common.keys import Keys

#importando a biblioteca do pyautogui para trabalhar com o tempo e teclas do teclado
import pyautogui as tempoPausaComputador
#usando o pyautogui para controlar as teclas do teclado
import pyautogui as teclasAtalhoTeclado
#usando o by para trabalhar com atualizações recentes
from selenium.webdriver.common.by import By

import sys

#Passamos autorizaçãso ao acesso as configuracóões do Chrome
meuNavegador = opcoes_selenium.Chrome()
meuNavegador.get('https://www.google.com.br/')

#aguarda o computador processar
tempoPausaComputador.sleep(2)

valorDigitado = input('qual a moeda desejada? ')

if valorDigitado == 'dolar':
    print('dolar hoje')
elif valorDigitado == 'euro':
    print('euro hoje')
else:
    print('valor invalido')
    sys.exit()
    

#procurando pelo elemento NAME e quando encontrador escrever a SEND_KEY
meuNavegador.find_element(By.NAME, 'q').send_keys(valorDigitado)

#retorna para o campo NAME "Enter"
meuNavegador.find_element(By.NAME, 'q').send_keys(Keys.RETURN)

#No resultado da pesquisa pegamos o XPATH e no meio pegamos o primeiro elemento da lista
valorDolarPeloGoogle = meuNavegador.find_elements(By.XPATH, '//*[@id="knowledge-currency__updatable-data-column"]/div[1]/div[2]/span[1]')[0].text

#aguarda o computador processar
tempoPausaComputador.sleep(2)

print(valorDolarPeloGoogle)
# Out:
# qual a moeda desejada? dolar
# dolar hoje
# 4,97

# %%
# !pip install xlsxwriter
# Out:
# ...
#   Obtaining dependency information for xlsxwriter from https://files.pythonhosted.org/packages/f7/3e/05ba2194cd5073602422859c949a4f21310a3c49bf8dccde9e03d4522b11/XlsxWriter-3.1.9-py3-none-any.whl.metadata
# ...
#    ---------------------------------------- 0.0/154.8 kB ? eta -:--:--
#    -- ------------------------------------- 10.2/154.8 kB ? eta -:--:--
#    ------- ------------------------------- 30.7/154.8 kB 445.2 kB/s eta 0:00:01
#    --------------- ----------------------- 61.4/154.8 kB 550.5 kB/s eta 0:00:01
#    ------------------------------ ------- 122.9/154.8 kB 804.6 kB/s eta 0:00:01
#    ------------------------------ ------- 122.9/154.8 kB 804.6 kB/s eta 0:00:01
#    -------------------------------------- 154.8/154.8 kB 617.6 kB/s eta 0:00:00
# ...

# %%
import xlsxwriter
import os

#caminho do arquivo criado e o final o nome do arquivo
nomeCaminhoArquivo = 'C:\\Users\\johnn\\Documents\\Curso RPA\\robo2 excels salvos\\Cadastro pessoas.xlsx'

planilhaCriada = xlsxwriter.Workbook(nomeCaminhoArquivo)
planilha1 = planilhaCriada.add_worksheet()

planilha1.write("A1", "Nome")
planilha1.write("B1", "Idade")
planilha1.write("A2", "Joana")
planilha1.write("B2", 29)
planilha1.write("A3", "Roberto")
planilha1.write("B3", 42)

#Fechando o arquivo do excel que esta em segundo plano
planilhaCriada.close()

#abre o arquivo
os.startfile(nomeCaminhoArquivo)

# %%
from selenium import webdriver as opcoes_selenium
from selenium.webdriver.common.keys import Keys

#importando a biblioteca do pyautogui para trabalhar com o tempo e teclas do teclado
import pyautogui as tempoPausaComputador
#usando o pyautogui para controlar as teclas do teclado
import pyautogui as teclasAtalhoTeclado
#usando o by para trabalhar com atualizações recentes
from selenium.webdriver.common.by import By

#Passamos autorizaçãso ao acesso as configuracóões do Chrome
meuNavegador = opcoes_selenium.Chrome()
meuNavegador.get('https://www.google.com.br/')

#aguarda o computador processar
tempoPausaComputador.sleep(2)

#procurando pelo elemento NAME e quando encontrador escrever a SEND_KEY
meuNavegador.find_element(By.NAME, 'q').send_keys('Dolar hoje')

#retorna para o campo NAME "Enter"
meuNavegador.find_element(By.NAME, 'q').send_keys(Keys.RETURN)

#aguarda o computador processar
tempoPausaComputador.sleep(2)

#No resultado da pesquisa pegamos o XPATH e no meio pegamos o primeiro elemento da lista
valorDolarPeloGoogle = meuNavegador.find_elements(By.XPATH, '//*[@id="knowledge-currency__updatable-data-column"]/div[1]/div[2]/span[1]')[0].text

#aguarda o computador processar
tempoPausaComputador.sleep(2)

print(valorDolarPeloGoogle)


#-----------------------------------------------------------------------------------------
#aguarda o computador processar
tempoPausaComputador.sleep(2)
#seleciona o campo de pesquisa novamente
meuNavegador.find_element(By.NAME, 'q').send_keys("")

#aguarda o computador processar
tempoPausaComputador.sleep(2)
#estamos usando o pyautogui para apertar a tecla TAB
teclasAtalhoTeclado.press('tab')
#aguarda o computador processar
tempoPausaComputador.sleep(2)
#estamos usando o pyautogui para apertar a tecla ENTER para limpar o campo de pesquisa
teclasAtalhoTeclado.press('enter')
#aguarda o computador processar
tempoPausaComputador.sleep(2)
#procurando pelo elemento NAME e quando encontrador escrever a SEND_KEY
meuNavegador.find_element(By.NAME, 'q').send_keys('Euro hoje')

#aguarda o computador processar
tempoPausaComputador.sleep(2)

#retorna para o campo NAME "Enter"
meuNavegador.find_element(By.NAME, 'q').send_keys(Keys.RETURN)

#aguarda o computador processar
tempoPausaComputador.sleep(2)

#No resultado da pesquisa pegamos o XPATH e no meio pegamos o primeiro elemento da lista
valorEuroPeloGoogle = meuNavegador.find_elements(By.XPATH, '//*[@id="knowledge-currency__updatable-data-column"]/div[1]/div[2]/span[1]')[0].text

#aguarda o computador processar
tempoPausaComputador.sleep(2)

print(valorEuroPeloGoogle)

#---------------------------------------------------------------------------------------------

import xlsxwriter
import os

#caminho do arquivo criado e o final o nome do arquivo
nomeCaminhoArquivo = 'C:\\Users\\johnn\\Documents\\Curso RPA\\robo2 excels salvos\\Dolar e Euro.xlsx'

planilhaCriada = xlsxwriter.Workbook(nomeCaminhoArquivo)
planilha1 = planilhaCriada.add_worksheet()

planilha1.write("A1", "Dolar")
planilha1.write("B1", "Euro")
planilha1.write("A2", valorDolarPeloGoogle)
planilha1.write("B2", valorEuroPeloGoogle)

#Subustituir a virgula por ponto deixando convertendo para float
valorDolarPeloGoogle = valorDolarPeloGoogle.replace(',','.')
valorEuroPeloGoogle = valorEuroPeloGoogle.replace(',','.')

#convertendo o valor do dolar e euro de string para float
valor_Dolar_tipo_float = float(valorDolarPeloGoogle)
valor_Euro_tipo_float = float(valorEuroPeloGoogle)

planilha1.write("A3", valor_Dolar_tipo_float)
planilha1.write("B3", valor_Euro_tipo_float)
planilha1.write("C3", valor_Dolar_tipo_float + valor_Euro_tipo_float )

#Fechando o arquivo do excel que esta em segundo plano
planilhaCriada.close()

#abre o arquivo
os.startfile(nomeCaminhoArquivo)
# Out:
# 4,97
# 5,35
